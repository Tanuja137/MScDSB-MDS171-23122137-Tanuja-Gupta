# %% [markdown]
# Create a Python Class for managing student details and marks.
# Define the class and implement the methods of the student class in a menu-driven program for different types of users

# %%
# class Student_details:
#     def __init__(self):
#         self.details=[]
#     def add_details(self,regno,name,course,subject,marks):
#         temp={
#             "Reg_no":regno,
#             "name":name,
#             "course":course,
#             "subject":subject,
#             "marks":marks
#         }
#         self.details.append(temp)

#     def print_details(self):
#         for i in self.details:
#             print(i)
       
# tanu=Student_details()
# # tanu.add_details(1,"tanuja","msc","cs",23)
# # tanu.add_details(2,"suraj","msc","cs",23)
# # tanu.print_details()
# while True:
#     print("Menu")
#     print("1. Add details")
#     print("2. Print details")
#     print("3.  ")
#     print("3. Exit")
#     choice=int(input("Enter your choice:"))
#     if choice==1:
#         regno=int(input("Enter the registration number:"))
#         name=input("Enter your name:")
#         course=input("Enter your course name:")
#         subject=input("Enter your subject:")
#         marks=int(input("Enter the marks:"))
#         tanu.add_details(regno,name,course,subject,marks)

#     elif choice==2:
#         tanu.print_details()
#     elif choice==3:
#         print("Thank you")
#         break
#     else:
#         print("invalid")
# Out:
# Menu
# 1. Add details
# 2. Print details
# 3. Exit
# Menu
# 1. Add details
# 2. Print details
# 3. Exit
# {'Reg_no': 1234, 'name': 'tanuja', 'course': 'python', 'subject': 'maths', 'marks': 45}
# Menu
# 1. Add details
# 2. Print details
# 3. Exit
# Thank you

# %%
# class student:
#     def __init__(self):
#         self.students=[]
#     def addStudent(self,name,regno,phone,email,sclass):
#         self.students[regno]={
#             'Name':name,
#             'Reg no':regno,
#             'Phone':phone,
#             'email':email,
#             'sclass':sclass
#         }
    
#     def students(self,regno,subject,mark):
#         self.students[regno]['marks'][subject]=mark

#     def display_student()

# %%
class student_details:
    def __init__(self):
        self.dicti = {}

    def create_student(self , name , course , division , roll , state , english , maths , statistics):
        temp = {
            "Name" : name , 
            "Course" : course , 
            "Division" : division , 
            "roll-no" : roll , 
            "state" : state,
            "English" : english,
            "Maths" : maths,
            "Statistics" : statistics
        }
        self.dicti[roll] = temp

    def search_student(self , roll):
        if roll in self.dicti:
            print(self.dicti[roll])



    def edit_student(self , roll , col , val):
        if roll in self.dicti:
            self.dicti[roll][col] = val
            print("Changes saved successfully")

    def print_students(self):
        print(self.dicti)

    def eixt_student():
        exit()

obj = student_details()

while True:
    print("Welcome to a menu drven programme for student management.")
    print("Please choose any option from the below ")
    print("1. Create Student")
    print("2. Search Student")
    print("3. Print Students")
    print("4. Edit Student")
    print("5. Exit")

    choice = int(input("Enter the option from the above: "))

    if choice == 1:
        name = input("Enter the name of the student: ")
        course = input("Enter the course of the student: ")
        division = input("Enter the division of the student: ")
        roll = input("Enter the roll number of the student")
        state = input("Enter the state of the student: ")
        english = input("Enter the marks of the english: ")
        maths = input("Enter the marks of the maths: ")
        statistics = input("Enter the marks of the statistics: ")
        obj.create_student(name , course , division , roll , state  , english , maths , statistics)
        print("Student added successfully")

    if choice == 2:
        roll = input("Enter the roll number : ")
        obj.search_student(roll)


    if choice == 3 :
        obj.print_students()
    
    if choice == 4 :
        roll = input("Enter the roll number of the student: ")
        col = input("Enter the field you want to edit: ")
        val = input("Enter the value you want to edit")
        obj.edit_student(roll , col , val)
        print("Value edited successfully.")

    if choice == 5:
        print("Thankyou. Visit again")
        break
# Out:
# Welcome to a menu drven programme for student management.
# Please choose any option from the below
# 1. Create Student
# 2. Search Student
# 3. Print Students
# 4. Edit Student
# 5. Exit
# Student added successfully
# Welcome to a menu drven programme for student management.
# Please choose any option from the below
# 1. Create Student
# 2. Search Student
# 3. Print Students
# 4. Edit Student
# 5. Exit
# Student added successfully
# Welcome to a menu drven programme for student management.
# Please choose any option from the below
# 1. Create Student
# 2. Search Student
# 3. Print Students
# 4. Edit Student
# 5. Exit
# {'123': {'Name': 'tanu', 'Course': 'msds', 'Division': '1', 'roll-no': '123', 'state': 'assam', 'English': '56', 'Maths': '78', 'Statistics': '89'}, '132': {'Name': 'stuty', 'Course': 'msds', 'Division': '2', 'roll-no': '132', 'state': 'tamil', 'English': '78', 'Maths': '98', 'Statistics': '56'}}
# Welcome to a menu drven programme for student management.
# Please choose any option from the below
# 1. Create Student
# 2. Search Student
# 3. Print Students
# 4. Edit Student
# 5. Exit
# Changes saved successfully
# Value edited successfully.
# Welcome to a menu drven programme for student management.
# Please choose any option from the below
# 1. Create Student
# 2. Search Student
# 3. Print Students
# 4. Edit Student
# 5. Exit
# {'123': {'Name': 'tanu', 'Course': 'msds', 'Division': '1', 'roll-no': '123', 'state': 'assam', 'English': '56', 'Maths': '78', 'Statistics': '89'}, '132': {'Name': 'stuty', 'Course': 'msds', 'Division': '2', 'roll-no': '132', 'state': 'tamil', 'English': '78', 'Maths': '98', 'Statistics': '56', 'name': 'taniya'}}
# Welcome to a menu drven programme for student management.
# Please choose any option from the below
# 1. Create Student
# 2. Search Student
# 3. Print Students
# 4. Edit Student
# 5. Exit
# Thankyou. Visit again
