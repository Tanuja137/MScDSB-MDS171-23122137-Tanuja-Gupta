# %%
import random # Importing library to use random()

items = ['Bourbon','Hide&Seek','GoodDay','ParleG','SoyaStick','Unibic','Patanjali','Sunfeast','Bournvita','Happy Happy'] #list of items
qty = [2,1,12,2,13,9,7,2,4,9] #list of quantity
price = [50,90,40,70,60,50,30,80,60,40] #Price List

i = 1 #initial value for i i.e iteration factor

while i<=100: # to get random values for eavh list 100 times
    r1 = random.randint(0,9) #r1 to store the randomly generated value used as an index value for Items List
    r2 = random.randint(0,9) #r2 to store the randomly generated value used as an index value for Qty List
    r3 = random.randint(0,9) #r3 to store the randomly generated value used as an index value for Price List

    # Printing all the random values
    print('Random Index from Items List',r1,'\n')   
    print('Random Index from Qty List',r2,'\n')
    print('Random Index from Price List',r3,'\n')

    item = items[r1] #item to store the element at r1 index in items list
    qt = qty[r2] #qt to store the element at r2 index in qty list
    pr = price[r3] #pr to store the element at r3 index in price list

    quantity = str(qt) #converting qty to string to enable writing it to the file
    cost = str(pr) #converting unit price to string to enable writing it to the file
    com = item+','+quantity+','+cost 
    print(com,'\n')
    
    file = open('23122137.csv','a') # Opening the csv file in append mode
    file.write(com) 
    file.write('\n') 
    file.close() 

    i = i + 1 #Next iteration
# Out:
# Random Index from Items List 2
#
# Random Index from Qty List 1
#
# Random Index from Price List 4
#
# GoodDay,1,60
#
# Random Index from Items List 3
#
# Random Index from Qty List 3
#
# Random Index from Price List 8
#
# ParleG,2,60
#
# Random Index from Items List 6
#
# Random Index from Qty List 8
#
# Random Index from Price List 0
#
# Patanjali,4,50
#
# Random Index from Items List 2
#
# Random Index from Qty List 9
#
# Random Index from Price List 4
#
# GoodDay,9,60
#
# Random Index from Items List 3
#
# Random Index from Qty List 1
#
# Random Index from Price List 9
#
# ParleG,1,40
#
# Random Index from Items List 6
#
# Random Index from Qty List 2
#
# Random Index from Price List 1
#
# Patanjali,12,90
#
# Random Index from Items List 8
#
# Random Index from Qty List 1
#
# Random Index from Price List 8
#
# Bournvita,1,60
#
# Random Index from Items List 7
#
# Random Index from Qty List 5
#
# Random Index from Price List 1
#
# Sunfeast,9,90
#
# Random Index from Items List 3
#
# Random Index from Qty List 3
#
# Random Index from Price List 8
#
# ParleG,2,60
#
# Random Index from Items List 8
#
# Random Index from Qty List 5
#
# Random Index from Price List 1
#
# Bournvita,9,90
#
# Random Index from Items List 7
#
# Random Index from Qty List 1
#
# Random Index from Price List 9
#
# Sunfeast,1,40
#
# Random Index from Items List 0
#
# Random Index from Qty List 4
#
# Random Index from Price List 7
#
# Bourbon,13,80
#
# Random Index from Items List 7
#
# Random Index from Qty List 1
#
# Random Index from Price List 4
#
# Sunfeast,1,60
#
# Random Index from Items List 2
#
# Random Index from Qty List 6
#
# Random Index from Price List 8
#
# GoodDay,7,60
#
# Random Index from Items List 7
#
# Random Index from Qty List 8
#
# Random Index from Price List 7
#
# Sunfeast,4,80
#
# Random Index from Items List 5
#
# Random Index from Qty List 2
#
# Random Index from Price List 6
#
# Unibic,12,30
#
# Random Index from Items List 2
#
# Random Index from Qty List 1
#
# Random Index from Price List 5
#
# GoodDay,1,50
#
# Random Index from Items List 8
#
# Random Index from Qty List 7
#
# Random Index from Price List 2
#
# Bournvita,2,40
#
# Random Index from Items List 3
#
# Random Index from Qty List 7
#
# Random Index from Price List 5
#
# ParleG,2,50
#
# Random Index from Items List 6
#
# Random Index from Qty List 6
#
# Random Index from Price List 9
#
# Patanjali,7,40
#
# Random Index from Items List 2
#
# Random Index from Qty List 7
#
# Random Index from Price List 4
#
# GoodDay,2,60
#
# Random Index from Items List 9
#
# Random Index from Qty List 6
#
# Random Index from Price List 6
#
# Happy Happy,7,30
#
# Random Index from Items List 0
#
# Random Index from Qty List 3
#
# Random Index from Price List 5
#
# Bourbon,2,50
#
# Random Index from Items List 6
#
# Random Index from Qty List 2
#
# Random Index from Price List 9
#
# Patanjali,12,40
#
# Random Index from Items List 2
#
# Random Index from Qty List 1
#
# Random Index from Price List 8
#
# GoodDay,1,60
#
# Random Index from Items List 8
#
# Random Index from Qty List 0
#
# Random Index from Price List 3
#
# Bournvita,2,70
#
# Random Index from Items List 7
#
# Random Index from Qty List 7
#
# Random Index from Price List 6
#
# Sunfeast,2,30
#
# Random Index from Items List 8
#
# Random Index from Qty List 1
#
# Random Index from Price List 6
#
# Bournvita,1,30
#
# Random Index from Items List 2
#
# Random Index from Qty List 8
#
# Random Index from Price List 7
#
# GoodDay,4,80
#
# Random Index from Items List 4
#
# Random Index from Qty List 2
#
# Random Index from Price List 5
#
# SoyaStick,12,50
#
# Random Index from Items List 3
#
# Random Index from Qty List 9
#
# Random Index from Price List 0
#
# ParleG,9,50
#
# Random Index from Items List 4
#
# Random Index from Qty List 3
#
# Random Index from Price List 5
#
# SoyaStick,2,50
#
# Random Index from Items List 8
#
# Random Index from Qty List 5
#
# Random Index from Price List 1
#
# Bournvita,9,90
#
# Random Index from Items List 9
#
# Random Index from Qty List 9
#
# Random Index from Price List 1
#
# Happy Happy,9,90
#
# Random Index from Items List 4
#
# Random Index from Qty List 2
#
# Random Index from Price List 1
#
# SoyaStick,12,90
#
# Random Index from Items List 6
#
# Random Index from Qty List 8
#
# Random Index from Price List 6
#
# Patanjali,4,30
#
# Random Index from Items List 2
#
# Random Index from Qty List 2
#
# Random Index from Price List 2
#
# GoodDay,12,40
#
# Random Index from Items List 3
#
# Random Index from Qty List 4
#
# Random Index from Price List 4
#
# ParleG,13,60
#
# Random Index from Items List 4
#
# Random Index from Qty List 8
#
# Random Index from Price List 7
#
# SoyaStick,4,80
#
# Random Index from Items List 9
#
# Random Index from Qty List 7
#
# Random Index from Price List 5
#
# Happy Happy,2,50
#
# Random Index from Items List 9
#
# Random Index from Qty List 6
#
# Random Index from Price List 6
#
# Happy Happy,7,30
#
# Random Index from Items List 9
#
# Random Index from Qty List 0
#
# Random Index from Price List 9
#
# Happy Happy,2,40
#
# Random Index from Items List 5
#
# Random Index from Qty List 2
#
# Random Index from Price List 1
#
# Unibic,12,90
#
# Random Index from Items List 6
#
# Random Index from Qty List 1
#
# Random Index from Price List 8
#
# Patanjali,1,60
#
# Random Index from Items List 9
#
# Random Index from Qty List 7
#
# Random Index from Price List 8
#
# Happy Happy,2,60
#
# Random Index from Items List 8
#
# Random Index from Qty List 4
#
# Random Index from Price List 8
#
# Bournvita,13,60
#
# Random Index from Items List 1
#
# Random Index from Qty List 7
#
# Random Index from Price List 8
#
# Hide&Seek,2,60
#
# Random Index from Items List 3
#
# Random Index from Qty List 0
#
# Random Index from Price List 8
#
# ParleG,2,60
#
# Random Index from Items List 5
#
# Random Index from Qty List 5
#
# Random Index from Price List 2
#
# Unibic,9,40
#
# Random Index from Items List 7
#
# Random Index from Qty List 0
#
# Random Index from Price List 9
#
# Sunfeast,2,40
#
# Random Index from Items List 6
#
# Random Index from Qty List 8
#
# Random Index from Price List 0
#
# Patanjali,4,50
#
# Random Index from Items List 4
#
# Random Index from Qty List 3
#
# Random Index from Price List 3
#
# SoyaStick,2,70
#
# Random Index from Items List 6
#
# Random Index from Qty List 6
#
# Random Index from Price List 3
#
# Patanjali,7,70
#
# Random Index from Items List 3
#
# Random Index from Qty List 9
#
# Random Index from Price List 4
#
# ParleG,9,60
#
# Random Index from Items List 8
#
# Random Index from Qty List 9
#
# Random Index from Price List 8
#
# Bournvita,9,60
#
# Random Index from Items List 6
#
# Random Index from Qty List 6
#
# Random Index from Price List 5
#
# Patanjali,7,50
#
# Random Index from Items List 7
#
# Random Index from Qty List 0
#
# Random Index from Price List 6
#
# Sunfeast,2,30
#
# Random Index from Items List 3
#
# Random Index from Qty List 9
#
# Random Index from Price List 3
#
# ParleG,9,70
#
# Random Index from Items List 1
#
# Random Index from Qty List 9
#
# Random Index from Price List 3
#
# Hide&Seek,9,70
#
# Random Index from Items List 4
#
# Random Index from Qty List 8
#
# Random Index from Price List 0
#
# SoyaStick,4,50
#
# Random Index from Items List 3
#
# Random Index from Qty List 7
#
# Random Index from Price List 0
#
# ParleG,2,50
#
# Random Index from Items List 9
#
# Random Index from Qty List 7
#
# Random Index from Price List 1
#
# Happy Happy,2,90
#
# Random Index from Items List 8
#
# Random Index from Qty List 6
#
# Random Index from Price List 9
#
# Bournvita,7,40
#
# Random Index from Items List 8
#
# Random Index from Qty List 6
#
# Random Index from Price List 1
#
# Bournvita,7,90
#
# Random Index from Items List 7
#
# Random Index from Qty List 4
#
# Random Index from Price List 9
#
# Sunfeast,13,40
#
# Random Index from Items List 7
#
# Random Index from Qty List 2
#
# Random Index from Price List 8
#
# Sunfeast,12,60
#
# Random Index from Items List 4
#
# Random Index from Qty List 4
#
# Random Index from Price List 2
#
# SoyaStick,13,40
#
# Random Index from Items List 7
#
# Random Index from Qty List 0
#
# Random Index from Price List 7
#
# Sunfeast,2,80
#
# Random Index from Items List 1
#
# Random Index from Qty List 8
#
# Random Index from Price List 1
#
# Hide&Seek,4,90
#
# Random Index from Items List 6
#
# Random Index from Qty List 4
#
# Random Index from Price List 5
#
# Patanjali,13,50
#
# Random Index from Items List 7
#
# Random Index from Qty List 3
#
# Random Index from Price List 3
#
# Sunfeast,2,70
#
# Random Index from Items List 7
#
# Random Index from Qty List 3
#
# Random Index from Price List 7
#
# Sunfeast,2,80
#
# Random Index from Items List 1
#
# Random Index from Qty List 6
#
# Random Index from Price List 7
#
# Hide&Seek,7,80
#
# Random Index from Items List 5
#
# Random Index from Qty List 9
#
# Random Index from Price List 5
#
# Unibic,9,50
#
# Random Index from Items List 0
#
# Random Index from Qty List 2
#
# Random Index from Price List 6
#
# Bourbon,12,30
#
# Random Index from Items List 0
#
# Random Index from Qty List 1
#
# Random Index from Price List 6
#
# Bourbon,1,30
#
# Random Index from Items List 5
#
# Random Index from Qty List 2
#
# Random Index from Price List 0
#
# Unibic,12,50
#
# Random Index from Items List 5
#
# Random Index from Qty List 0
#
# Random Index from Price List 4
#
# Unibic,2,60
#
# Random Index from Items List 5
#
# Random Index from Qty List 2
#
# Random Index from Price List 3
#
# Unibic,12,70
#
# Random Index from Items List 9
#
# Random Index from Qty List 2
#
# Random Index from Price List 8
#
# Happy Happy,12,60
#
# Random Index from Items List 4
#
# Random Index from Qty List 1
#
# Random Index from Price List 2
#
# SoyaStick,1,40
#
# Random Index from Items List 9
#
# Random Index from Qty List 4
#
# Random Index from Price List 4
#
# Happy Happy,13,60
#
# Random Index from Items List 4
#
# Random Index from Qty List 6
#
# Random Index from Price List 2
#
# SoyaStick,7,40
#
# Random Index from Items List 2
#
# Random Index from Qty List 2
#
# Random Index from Price List 5
#
# GoodDay,12,50
#
# Random Index from Items List 5
#
# Random Index from Qty List 1
#
# Random Index from Price List 2
#
# Unibic,1,40
#
# Random Index from Items List 3
#
# Random Index from Qty List 4
#
# Random Index from Price List 9
#
# ParleG,13,40
#
# Random Index from Items List 2
#
# Random Index from Qty List 3
#
# Random Index from Price List 2
#
# GoodDay,2,40
#
# Random Index from Items List 1
#
# Random Index from Qty List 6
#
# Random Index from Price List 5
#
# Hide&Seek,7,50
#
# Random Index from Items List 5
#
# Random Index from Qty List 0
#
# Random Index from Price List 6
#
# Unibic,2,30
#
# Random Index from Items List 3
#
# Random Index from Qty List 1
#
# Random Index from Price List 0
#
# ParleG,1,50
#
# Random Index from Items List 4
#
# Random Index from Qty List 8
#
# Random Index from Price List 5
#
# SoyaStick,4,50
#
# Random Index from Items List 2
#
# Random Index from Qty List 6
#
# Random Index from Price List 7
#
# GoodDay,7,80
#
# Random Index from Items List 7
#
# Random Index from Qty List 4
#
# Random Index from Price List 1
#
# Sunfeast,13,90
#
# Random Index from Items List 5
#
# Random Index from Qty List 9
#
# Random Index from Price List 1
#
# Unibic,9,90
#
# Random Index from Items List 5
#
# Random Index from Qty List 4
#
# Random Index from Price List 6
#
# Unibic,13,30
#
# Random Index from Items List 8
#
# Random Index from Qty List 3
#
# Random Index from Price List 5
#
# Bournvita,2,50
#
# Random Index from Items List 6
#
# Random Index from Qty List 4
#
# Random Index from Price List 3
#
# Patanjali,13,70
#
# Random Index from Items List 7
#
# Random Index from Qty List 8
#
# Random Index from Price List 9
#
# Sunfeast,4,40
#
# Random Index from Items List 7
#
# Random Index from Qty List 1
#
# Random Index from Price List 7
#
# Sunfeast,1,80
#
# Random Index from Items List 9
#
# Random Index from Qty List 2
#
# Random Index from Price List 3
#
# Happy Happy,12,70
